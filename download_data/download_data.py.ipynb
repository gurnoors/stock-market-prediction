# %%
# url = 'https://www.quandl.com/api/v3/datasets/{stock_code}?&api_key={api_key}'
url = 'https://www.quandl.com/api/v3/datasets/{stock_code}.csv?api_key={api_key}'
stock_code = 'BSE/BOM517421'
api_key = 'mTacgYukWuygF5aiwzvm'

formatted_url = url.format(stock_code=stock_code, api_key=api_key)
print formatted_url
# Out:
# https://www.quandl.com/api/v3/datasets/BSE/BOM517421.csv?api_key=mTacgYukWuygF5aiwzvm

# %%
codes = []
with open('BSE-datasets-codes.csv') as fp:
    for line in fp:
        codes.append(line.split(',')[0])
    
print (codes[0], "len=", len(codes))
# Out:
# ('BSE/BOM500002', 'len=', 4566)

# %%
import urllib2, json
import os.path, os

i=0
if not os.path.exists('data'):
    os.mkdir('data')

log_file = open('errors.log', 'w')

count = 0
for code in codes:
    try:
        print ('downloading ' + str(code) + ' (file {x} of {y})').format(x=count, y=len(codes))
        formatted_url = url.format(stock_code=code, api_key=api_key)
        resp = urllib2.urlopen(formatted_url)

        file_name = 'data/' + code.replace('/', '_') + '.csv'
        while os.path.isfile(file_name):
            file_name = 'data/' + code.replace('/', '_') + '_' + str(i) + '.csv'
            i += 1

        with open(file_name, 'w') as fp:
            fp.write(resp.read())
        count += 1
    except Exception as e:
        print 'failed to download ' + code
        print str(e)
        log_file.write(code + ' | ' + str(e) + '\n')

log_file.close()

print 'Number of stocks in BSE: %d' % len(codes)
print 'Number of files downloaded %d' % count
# Out:
# downloading BSE/BOM500002
# downloading BSE/BOM500003
# downloading BSE/BOM500008
# downloading BSE/BOM500009
# downloading BSE/BOM500010
# downloading BSE/BOM500012
# downloading BSE/BOM500013
# downloading BSE/BOM500014
# downloading BSE/BOM500020
# downloading BSE/BOM500023
# downloading BSE/BOM500024
# downloading BSE/BOM500027
# downloading BSE/BOM500028
# downloading BSE/BOM500029
# downloading BSE/BOM500030
# downloading BSE/BOM500031
# downloading BSE/BOM500032
# downloading BSE/BOM500033
# downloading BSE/BOM500034
# downloading BSE/BOM500038
# downloading BSE/BOM500039
# downloading BSE/BOM500040
# downloading BSE/BOM500041
# downloading BSE/BOM500042
# downloading BSE/BOM500043
# downloading BSE/BOM500046
# downloading BSE/BOM500048
# downloading BSE/BOM500049
# downloading BSE/BOM500051
# downloading BSE/BOM500052
# downloading BSE/BOM500055
# downloading BSE/BOM500057
# downloading BSE/BOM500058
# downloading BSE/BOM500059
# downloading BSE/BOM500060
# downloading BSE/BOM500067
# downloading BSE/BOM500068
# downloading BSE/BOM500069
# downloading BSE/BOM500074
# downloading BSE/BOM500077
# downloading BSE/BOM500078
# downloading BSE/BOM500083
# downloading BSE/BOM500084
# downloading BSE/BOM500085
# downloading BSE/BOM500086
# downloading BSE/BOM500087
# downloading BSE/BOM500089
# downloading BSE/BOM500092
# downloading BSE/BOM500093
# downloading BSE/BOM500095
# downloading BSE/BOM500096
# downloading BSE/BOM500097
# downloading BSE/BOM500101
# downloading BSE/BOM500102
# downloading BSE/BOM500103
# downloading BSE/BOM500104
# downloading BSE/BOM500106
# downloading BSE/BOM500108
# downloading BSE/BOM500109
# downloading BSE/BOM500110
# downloading BSE/BOM500111
# downloading BSE/BOM500112
# downloading BSE/BOM500113
# downloading BSE/BOM500114
# downloading BSE/BOM500116
# downloading BSE/BOM500117
# downloading BSE/BOM500119
# downloading BSE/BOM500120
# downloading BSE/BOM500123
# downloading BSE/BOM500124
# downloading BSE/BOM500125
# downloading BSE/BOM500126
# downloading BSE/BOM500128
# downloading BSE/BOM500132
# downloading BSE/BOM500133
# downloading BSE/BOM500134
# downloading BSE/BOM500135
# downloading BSE/BOM500136
# downloading BSE/BOM500139
# downloading BSE/BOM500141
# downloading BSE/BOM500142
# downloading BSE/BOM500143
# downloading BSE/BOM500144
# downloading BSE/BOM500145
# downloading BSE/BOM500147
# downloading BSE/BOM500148
# downloading BSE/BOM500150
# downloading BSE/BOM500151
# downloading BSE/BOM500153
# downloading BSE/BOM500155
# downloading BSE/BOM500159
# downloading BSE/BOM500160
# downloading BSE/BOM500162
# downloading BSE/BOM500163
# downloading BSE/BOM500164
# downloading BSE/BOM500165
# downloading BSE/BOM500166
# downloading BSE/BOM500168
# downloading BSE/BOM500170
# downloading BSE/BOM500171
# downloading BSE/BOM500173
# downloading BSE/BOM500174
# downloading BSE/BOM500179
# downloading BSE/BOM500180
# downloading BSE/BOM500182
# downloading BSE/BOM500183
# downloading BSE/BOM500184
# downloading BSE/BOM500185
# downloading BSE/BOM500186
# downloading BSE/BOM500187
# downloading BSE/BOM500188
# downloading BSE/BOM500189
# downloading BSE/BOM500191
# downloading BSE/BOM500192
# downloading BSE/BOM500193
# downloading BSE/BOM500199
# downloading BSE/BOM500201
# downloading BSE/BOM500202
# downloading BSE/BOM500206
# downloading BSE/BOM500207
# downloading BSE/BOM500209
# downloading BSE/BOM500210
# downloading BSE/BOM500211
# downloading BSE/BOM500212
# downloading BSE/BOM500213
# downloading BSE/BOM500214
# downloading BSE/BOM500215
# downloading BSE/BOM500219
# downloading BSE/BOM500220
# downloading BSE/BOM500222
# downloading BSE/BOM500223
# downloading BSE/BOM500227
# downloading BSE/BOM500228
# downloading BSE/BOM500231
# downloading BSE/BOM500233
# downloading BSE/BOM500234
# downloading BSE/BOM500235
# downloading BSE/BOM500236
# downloading BSE/BOM500238
# downloading BSE/BOM500239
# downloading BSE/BOM500240
# downloading BSE/BOM500241
# downloading BSE/BOM500243
# downloading BSE/BOM500245
# downloading BSE/BOM500246
# downloading BSE/BOM500247
# downloading BSE/BOM500248
# downloading BSE/BOM500249
# downloading BSE/BOM500250
# downloading BSE/BOM500251
# downloading BSE/BOM500252
# downloading BSE/BOM500253
# downloading BSE/BOM500254
# downloading BSE/BOM500255
# downloading BSE/BOM500256
# downloading BSE/BOM500257
# downloading BSE/BOM500259
# downloading BSE/BOM500260
# downloading BSE/BOM500264
# downloading BSE/BOM500265
# downloading BSE/BOM500266
# downloading BSE/BOM500267
# downloading BSE/BOM500268
# downloading BSE/BOM500271
# downloading BSE/BOM500277
# downloading BSE/BOM500279
# downloading BSE/BOM500280
# downloading BSE/BOM500284
# downloading BSE/BOM500285
# downloading BSE/BOM500288
# downloading BSE/BOM500290
# downloading BSE/BOM500292
# downloading BSE/BOM500294
# downloading BSE/BOM500295
# downloading BSE/BOM500296
# downloading BSE/BOM500298
# downloading BSE/BOM500300
# downloading BSE/BOM500301
# downloading BSE/BOM500302
# downloading BSE/BOM500303
# downloading BSE/BOM500304
# downloading BSE/BOM500306
# downloading BSE/BOM500307
# downloading BSE/BOM500310
# downloading BSE/BOM500312
# downloading BSE/BOM500313
# downloading BSE/BOM500314
# downloading BSE/BOM500315
# downloading BSE/BOM500317
# downloading BSE/BOM500318
# downloading BSE/BOM500319
# downloading BSE/BOM500322
# downloading BSE/BOM500325
# downloading BSE/BOM500327
# downloading BSE/BOM500329
# downloading BSE/BOM500330
# downloading BSE/BOM500331
# downloading BSE/BOM500333
# downloading BSE/BOM500335
# downloading BSE/BOM500336
# downloading BSE/BOM500337
# downloading BSE/BOM500338
# downloading BSE/BOM500339
# downloading BSE/BOM500343
# downloading BSE/BOM500346
# downloading BSE/BOM500350
# downloading BSE/BOM500354
# downloading BSE/BOM500355
# downloading BSE/BOM500356
# downloading BSE/BOM500357
# downloading BSE/BOM500358
# downloading BSE/BOM500359
# downloading BSE/BOM500360
# downloading BSE/BOM500365
# downloading BSE/BOM500366
# downloading BSE/BOM500367
# downloading BSE/BOM500368
# downloading BSE/BOM500370
# downloading BSE/BOM500371
# downloading BSE/BOM500372
# downloading BSE/BOM500378
# downloading BSE/BOM500380
# downloading BSE/BOM500387
# downloading BSE/BOM500388
# downloading BSE/BOM500390
# downloading BSE/BOM500399
# downloading BSE/BOM500400
# downloading BSE/BOM500402
# downloading BSE/BOM500403
# downloading BSE/BOM500404
# downloading BSE/BOM500405
# downloading BSE/BOM500407
# downloading BSE/BOM500408
# downloading BSE/BOM500410
# downloading BSE/BOM500411
# downloading BSE/BOM500412
# downloading BSE/BOM500413
# downloading BSE/BOM500414
# downloading BSE/BOM500418
# downloading BSE/BOM500420
# downloading BSE/BOM500422
# downloading BSE/BOM500425
# downloading BSE/BOM500426
# downloading BSE/BOM500429
# downloading BSE/BOM500439
# downloading BSE/BOM500440
# downloading BSE/BOM500444
# downloading BSE/BOM500449
# downloading BSE/BOM500450
# downloading BSE/BOM500456
# downloading BSE/BOM500458
# downloading BSE/BOM500459
# downloading BSE/BOM500460
# downloading BSE/BOM500463
# downloading BSE/BOM500464
# downloading BSE/BOM500465
# downloading BSE/BOM500467
# downloading BSE/BOM500469
# downloading BSE/BOM500470
# downloading BSE/BOM500472
# downloading BSE/BOM500477
# downloading BSE/BOM500480
# downloading BSE/BOM500483
# downloading BSE/BOM500488
# downloading BSE/BOM500490
# downloading BSE/BOM500493
# downloading BSE/BOM500495
# downloading BSE/BOM500500
# downloading BSE/BOM500510
# downloading BSE/BOM500520
# downloading BSE/BOM500530
# downloading BSE/BOM500540
# downloading BSE/BOM500547
# downloading BSE/BOM500550
# downloading BSE/BOM500570
# downloading BSE/BOM500575
# downloading BSE/BOM500620
# downloading BSE/BOM500630
# downloading BSE/BOM500645
# downloading BSE/BOM500650
# downloading BSE/BOM500655
# downloading BSE/BOM500660
# downloading BSE/BOM500670
# downloading BSE/BOM500672
# downloading BSE/BOM500674
# downloading BSE/BOM500676
# downloading BSE/BOM500680
# downloading BSE/BOM500690
# downloading BSE/BOM500696
# downloading BSE/BOM500710
# downloading BSE/BOM500730
# downloading BSE/BOM500770
# downloading BSE/BOM500777
# downloading BSE/BOM500780
# downloading BSE/BOM500790
# downloading BSE/BOM500800
# downloading BSE/BOM500820
# downloading BSE/BOM500825
# downloading BSE/BOM500830
# downloading BSE/BOM500840
# downloading BSE/BOM500850
# downloading BSE/BOM500870
# downloading BSE/BOM500875
# downloading BSE/BOM500877
# downloading BSE/BOM500878
# downloading BSE/BOM500890
# downloading BSE/BOM500940
# downloading BSE/BOM500945
# downloading BSE/BOM501061
# downloading BSE/BOM501110
# downloading BSE/BOM501111
# downloading BSE/BOM501148
# downloading BSE/BOM501150
# downloading BSE/BOM501151
# downloading BSE/BOM501154
# downloading BSE/BOM501179
# downloading BSE/BOM501209
# downloading BSE/BOM501233
# downloading BSE/BOM501242
# downloading BSE/BOM501261
# downloading BSE/BOM501267
# downloading BSE/BOM501295
# downloading BSE/BOM501298
# downloading BSE/BOM501301
# downloading BSE/BOM501311
# downloading BSE/BOM501343
# downloading BSE/BOM501351
# downloading BSE/BOM501368
# downloading BSE/BOM501370
# downloading BSE/BOM501386
# downloading BSE/BOM501391
# downloading BSE/BOM501421
# downloading BSE/BOM501423
# downloading BSE/BOM501425
# downloading BSE/BOM501430
# downloading BSE/BOM501455
# downloading BSE/BOM501471
# downloading BSE/BOM501473
# downloading BSE/BOM501477
# downloading BSE/BOM501482
# downloading BSE/BOM501622
# downloading BSE/BOM501630
# downloading BSE/BOM501700
# downloading BSE/BOM501756
# downloading BSE/BOM501827
# downloading BSE/BOM501831
# downloading BSE/BOM501833
# downloading BSE/BOM501848
# downloading BSE/BOM501945
# downloading BSE/BOM502015
# downloading BSE/BOM502090
# downloading BSE/BOM502137
# downloading BSE/BOM502150
# downloading BSE/BOM502157
# downloading BSE/BOM502165
# downloading BSE/BOM502168
# downloading BSE/BOM502175
# downloading BSE/BOM502180
# downloading BSE/BOM502216
# downloading BSE/BOM502219
# downloading BSE/BOM502223
# downloading BSE/BOM502250
# downloading BSE/BOM502271
# downloading BSE/BOM502281
# downloading BSE/BOM502294
# downloading BSE/BOM502330
# downloading BSE/BOM502352
# downloading BSE/BOM502355
# downloading BSE/BOM502405
# downloading BSE/BOM502407
# downloading BSE/BOM502420
# downloading BSE/BOM502445
# downloading BSE/BOM502448
# downloading BSE/BOM502450
# downloading BSE/BOM502455
# downloading BSE/BOM502460
# downloading BSE/BOM502465
# downloading BSE/BOM502473
# downloading BSE/BOM502563
# downloading BSE/BOM502587
# downloading BSE/BOM502589
# downloading BSE/BOM502742
# downloading BSE/BOM502761
# downloading BSE/BOM502820
# downloading BSE/BOM502850
# downloading BSE/BOM502865
# downloading BSE/BOM502873
# downloading BSE/BOM502893
# downloading BSE/BOM502901
# downloading BSE/BOM502933
# downloading BSE/BOM502937
# downloading BSE/BOM502958
# downloading BSE/BOM502986
# downloading BSE/BOM502995
# downloading BSE/BOM503015
# downloading BSE/BOM503031
# downloading BSE/BOM503100
# downloading BSE/BOM503092
# downloading BSE/BOM503101
# downloading BSE/BOM503127
# downloading BSE/BOM503162
# downloading BSE/BOM503169
# downloading BSE/BOM503205
# downloading BSE/BOM503229
# downloading BSE/BOM503310
# downloading BSE/BOM503349
# downloading BSE/BOM503624
# downloading BSE/BOM503630
# downloading BSE/BOM503635
# downloading BSE/BOM503637
# downloading BSE/BOM503641
# downloading BSE/BOM503657
# downloading BSE/BOM503659
# downloading BSE/BOM503663
# downloading BSE/BOM503669
# downloading BSE/BOM503675
# downloading BSE/BOM503681
# downloading BSE/BOM503685
# downloading BSE/BOM503689
# downloading BSE/BOM503691
# downloading BSE/BOM503699
# downloading BSE/BOM503722
# downloading BSE/BOM503772
# downloading BSE/BOM503776
# downloading BSE/BOM503780
# downloading BSE/BOM503796
# downloading BSE/BOM503804
# downloading BSE/BOM503806
# downloading BSE/BOM503811
# downloading BSE/BOM503816
# downloading BSE/BOM503823
# downloading BSE/BOM503831
# downloading BSE/BOM503837
# downloading BSE/BOM503863
# downloading BSE/BOM503873
# downloading BSE/BOM503881
# downloading BSE/BOM503893
# downloading BSE/BOM503940
# downloading BSE/BOM503960
# downloading BSE/BOM504000
# downloading BSE/BOM504008
# downloading BSE/BOM504028
# downloading BSE/BOM504036
# downloading BSE/BOM504058
# downloading BSE/BOM504067
# downloading BSE/BOM504076
# downloading BSE/BOM504080
# downloading BSE/BOM504084
# downloading BSE/BOM504092
# downloading BSE/BOM504093
# downloading BSE/BOM504112
# downloading BSE/BOM504132
# downloading BSE/BOM504176
# downloading BSE/BOM504180
# downloading BSE/BOM504212
# downloading BSE/BOM504220
# downloading BSE/BOM504240
# downloading BSE/BOM504256
# downloading BSE/BOM504258
# downloading BSE/BOM504269
# downloading BSE/BOM504286
# downloading BSE/BOM504288
# downloading BSE/BOM504335
# downloading BSE/BOM504336
# downloading BSE/BOM504340
# downloading BSE/BOM504341
# downloading BSE/BOM504345
# downloading BSE/BOM504351
# downloading BSE/BOM504353
# downloading BSE/BOM504356
# downloading BSE/BOM504358
# downloading BSE/BOM504360
# downloading BSE/BOM504365
# downloading BSE/BOM504367
# downloading BSE/BOM504369
# downloading BSE/BOM504370
# downloading BSE/BOM504375
# downloading BSE/BOM504378
# downloading BSE/BOM504380
# downloading BSE/BOM504382
# downloading BSE/BOM504387
# downloading BSE/BOM504390
# downloading BSE/BOM504392
# downloading BSE/BOM504398
# downloading BSE/BOM504605
# downloading BSE/BOM504614
# downloading BSE/BOM504629
# downloading BSE/BOM504643
# downloading BSE/BOM504646
# downloading BSE/BOM504671
# downloading BSE/BOM504673
# downloading BSE/BOM504697
# downloading BSE/BOM504701
# downloading BSE/BOM504731
# downloading BSE/BOM504741
# downloading BSE/BOM504746
# downloading BSE/BOM504786
# downloading BSE/BOM504810
# downloading BSE/BOM504823
# downloading BSE/BOM504840
# downloading BSE/BOM504864
# downloading BSE/BOM504879
# downloading BSE/BOM504903
# downloading BSE/BOM504908
# downloading BSE/BOM504918
# downloading BSE/BOM504959
# downloading BSE/BOM504960
# downloading BSE/BOM504961
# downloading BSE/BOM504966
# downloading BSE/BOM504973
# downloading BSE/BOM504988
# downloading BSE/BOM504991
# downloading BSE/BOM505010
# downloading BSE/BOM505029
# downloading BSE/BOM505036
# downloading BSE/BOM505052
# downloading BSE/BOM505075
# downloading BSE/BOM505141
# downloading BSE/BOM505160
# downloading BSE/BOM505163
# downloading BSE/BOM505192
# downloading BSE/BOM505196
# downloading BSE/BOM505200
# downloading BSE/BOM505212
# downloading BSE/BOM505216
# downloading BSE/BOM505230
# downloading BSE/BOM505232
# downloading BSE/BOM505242
# downloading BSE/BOM505250
# downloading BSE/BOM505255
# downloading BSE/BOM505283
# downloading BSE/BOM505285
# downloading BSE/BOM505299
# downloading BSE/BOM505302
# downloading BSE/BOM505320
# downloading BSE/BOM505324
# downloading BSE/BOM505336
# downloading BSE/BOM505343
# downloading BSE/BOM505355
# downloading BSE/BOM505358
# downloading BSE/BOM505368
# downloading BSE/BOM505400
# downloading BSE/BOM505412
# downloading BSE/BOM505502
# downloading BSE/BOM505504
# downloading BSE/BOM505506
# downloading BSE/BOM505509
# downloading BSE/BOM505513
# downloading BSE/BOM505523
# downloading BSE/BOM505525
# downloading BSE/BOM505526
# downloading BSE/BOM505529
# downloading BSE/BOM505530
# downloading BSE/BOM505533
# downloading BSE/BOM505537
# downloading BSE/BOM505539
# downloading BSE/BOM505576
# downloading BSE/BOM505585
# downloading BSE/BOM505590
# downloading BSE/BOM505592
# downloading BSE/BOM505594
# downloading BSE/BOM505650
# downloading BSE/BOM505658
# downloading BSE/BOM505665
# downloading BSE/BOM505681
# downloading BSE/BOM505685
# downloading BSE/BOM505688
# downloading BSE/BOM505690
# downloading BSE/BOM505693
# downloading BSE/BOM505700
# downloading BSE/BOM505703
# downloading BSE/BOM505710
# downloading BSE/BOM505711
# downloading BSE/BOM505712
# downloading BSE/BOM505714
# downloading BSE/BOM505720
# downloading BSE/BOM505725
# downloading BSE/BOM505726
# downloading BSE/BOM505729
# downloading BSE/BOM505737
# downloading BSE/BOM505744
# downloading BSE/BOM505750
# downloading BSE/BOM505790
# downloading BSE/BOM505797
# downloading BSE/BOM505800
# downloading BSE/BOM505807
# downloading BSE/BOM505817
# downloading BSE/BOM505827
# downloading BSE/BOM505840
# downloading BSE/BOM505850
# downloading BSE/BOM505854
# downloading BSE/BOM505872
# downloading BSE/BOM505890
# downloading BSE/BOM505893
# downloading BSE/BOM505930
# downloading BSE/BOM505978
# downloading BSE/BOM505982
# downloading BSE/BOM506003
# downloading BSE/BOM506016
# downloading BSE/BOM506022
# downloading BSE/BOM506027
# downloading BSE/BOM506041
# downloading BSE/BOM506074
# downloading BSE/BOM506076
# downloading BSE/BOM506079
# downloading BSE/BOM506103
# downloading BSE/BOM506105
# downloading BSE/BOM506109
# downloading BSE/BOM506113
# downloading BSE/BOM506120
# downloading BSE/BOM506122
# downloading BSE/BOM506128
# downloading BSE/BOM506131
# downloading BSE/BOM506134
# downloading BSE/BOM506142
# downloading BSE/BOM506146
# downloading BSE/BOM506159
# downloading BSE/BOM506161
# downloading BSE/BOM506166
# downloading BSE/BOM506170
# downloading BSE/BOM506180
# downloading BSE/BOM506184
# downloading BSE/BOM506186
# downloading BSE/BOM506194
# downloading BSE/BOM506196
# downloading BSE/BOM506197
# downloading BSE/BOM506222
# downloading BSE/BOM506230
# downloading BSE/BOM506235
# downloading BSE/BOM506248
# downloading BSE/BOM506260
# downloading BSE/BOM506261
# downloading BSE/BOM506285
# downloading BSE/BOM506313
# downloading BSE/BOM506315
# downloading BSE/BOM506365
# downloading BSE/BOM506390
# downloading BSE/BOM506395
# downloading BSE/BOM506401
# downloading BSE/BOM506405
# downloading BSE/BOM506414
# downloading BSE/BOM506457
# downloading BSE/BOM506480
# downloading BSE/BOM506520
# downloading BSE/BOM506522
# downloading BSE/BOM506525
# downloading BSE/BOM506528
# downloading BSE/BOM506530
# downloading BSE/BOM506532
# downloading BSE/BOM506543
# downloading BSE/BOM506579
# downloading BSE/BOM506590
# downloading BSE/BOM506597
# downloading BSE/BOM506605
# downloading BSE/BOM506615
# downloading BSE/BOM506618
# downloading BSE/BOM506640
# downloading BSE/BOM506642
# downloading BSE/BOM506655
# downloading BSE/BOM506685
# downloading BSE/BOM506687
# downloading BSE/BOM506690
# downloading BSE/BOM506720
# downloading BSE/BOM506734
# downloading BSE/BOM506767
# downloading BSE/BOM506803
# downloading BSE/BOM506808
# downloading BSE/BOM506820
# downloading BSE/BOM506822
# downloading BSE/BOM506852
# downloading BSE/BOM506854
# downloading BSE/BOM506858
# downloading BSE/BOM506863
# downloading BSE/BOM506867
# downloading BSE/BOM506874
# downloading BSE/BOM506879
# downloading BSE/BOM506894
# downloading BSE/BOM506910
# downloading BSE/BOM506919
# downloading BSE/BOM506938
# downloading BSE/BOM506943
# downloading BSE/BOM506947
# downloading BSE/BOM506971
# downloading BSE/BOM506975
# downloading BSE/BOM506981
# downloading BSE/BOM506985
# downloading BSE/BOM506991
# downloading BSE/BOM507155
# downloading BSE/BOM507180
# downloading BSE/BOM507205
# downloading BSE/BOM507260
# downloading BSE/BOM507265
# downloading BSE/BOM507300
# downloading BSE/BOM507315
# downloading BSE/BOM507405
# downloading BSE/BOM507410
# downloading BSE/BOM507435
# downloading BSE/BOM507438
# downloading BSE/BOM507442
# downloading BSE/BOM507446
# downloading BSE/BOM507450
# downloading BSE/BOM507458
# downloading BSE/BOM507474
# downloading BSE/BOM507486
# downloading BSE/BOM507488
# downloading BSE/BOM507490
# downloading BSE/BOM507498
# downloading BSE/BOM507506
# downloading BSE/BOM507508
# downloading BSE/BOM507514
# downloading BSE/BOM507515
# downloading BSE/BOM507522
# downloading BSE/BOM507525
# downloading BSE/BOM507526
# downloading BSE/BOM507528
# downloading BSE/BOM507543
# downloading BSE/BOM507552
# downloading BSE/BOM507580
# downloading BSE/BOM507598
# downloading BSE/BOM507609
# downloading BSE/BOM507621
# downloading BSE/BOM507645
# downloading BSE/BOM507649
# downloading BSE/BOM507652
# downloading BSE/BOM507663
# downloading BSE/BOM507685
# downloading BSE/BOM507690
# downloading BSE/BOM507717
# downloading BSE/BOM507747
# downloading BSE/BOM507753
# downloading BSE/BOM507759
# downloading BSE/BOM507779
# downloading BSE/BOM507785
# downloading BSE/BOM507789
# downloading BSE/BOM507794
# downloading BSE/BOM507813
# downloading BSE/BOM507815
# downloading BSE/BOM507817
# downloading BSE/BOM507828
# downloading BSE/BOM507833
# downloading BSE/BOM507836
# downloading BSE/BOM507852
# downloading BSE/BOM507864
# downloading BSE/BOM507870
# downloading BSE/BOM507872
# downloading BSE/BOM507878
# downloading BSE/BOM507880
# downloading BSE/BOM507886
# downloading BSE/BOM507892
# downloading BSE/BOM507894
# downloading BSE/BOM507910
# downloading BSE/BOM507912
# downloading BSE/BOM507917
# downloading BSE/BOM507918
# downloading BSE/BOM507938
# downloading BSE/BOM507944
# downloading BSE/BOM507946
# downloading BSE/BOM507948
# downloading BSE/BOM507952
# downloading BSE/BOM507960
# downloading BSE/BOM507962
# downloading BSE/BOM507966
# failed to download BSE/BOM507966
# HTTP Error 500: Internal Server Error
# downloading BSE/BOM507968
# downloading BSE/BOM507970
# downloading BSE/BOM507981
# downloading BSE/BOM507984
# downloading BSE/BOM507987
# downloading BSE/BOM507998
# downloading BSE/BOM508136
# downloading BSE/BOM508306
# downloading BSE/BOM508486
# downloading BSE/BOM508494
# downloading BSE/BOM508571
# downloading BSE/BOM508664
# downloading BSE/BOM508670
# downloading BSE/BOM508807
# downloading BSE/BOM508814
# downloading BSE/BOM508860
# downloading BSE/BOM508867
# downloading BSE/BOM508869
# downloading BSE/BOM508875
# downloading BSE/BOM508900
# downloading BSE/BOM508905
# downloading BSE/BOM508906
# downloading BSE/BOM508918
# downloading BSE/BOM508922
# downloading BSE/BOM508929
# downloading BSE/BOM508933
# downloading BSE/BOM508939
# downloading BSE/BOM508941
# downloading BSE/BOM508954
# downloading BSE/BOM508956
# downloading BSE/BOM508961
# downloading BSE/BOM508963
# downloading BSE/BOM508969
# downloading BSE/BOM508976
# downloading BSE/BOM508980
# downloading BSE/BOM508982
# downloading BSE/BOM508989
# downloading BSE/BOM508993
# downloading BSE/BOM508996
# downloading BSE/BOM508998
# downloading BSE/BOM509003
# downloading BSE/BOM509009
# downloading BSE/BOM509015
# downloading BSE/BOM509020
# downloading BSE/BOM509024
# downloading BSE/BOM509026
# downloading BSE/BOM509038
# downloading BSE/BOM509040
# downloading BSE/BOM509046
# downloading BSE/BOM509048
# downloading BSE/BOM509051
# downloading BSE/BOM509053
# downloading BSE/BOM509055
# downloading BSE/BOM509069
# downloading BSE/BOM509073
# downloading BSE/BOM509077
# downloading BSE/BOM509079
# downloading BSE/BOM509084
# downloading BSE/BOM509110
# downloading BSE/BOM509130
# downloading BSE/BOM509148
# downloading BSE/BOM509152
# downloading BSE/BOM509162
# downloading BSE/BOM509196
# downloading BSE/BOM509220
# downloading BSE/BOM509243
# downloading BSE/BOM509438
# downloading BSE/BOM509449
# downloading BSE/BOM509470
# downloading BSE/BOM509472
# downloading BSE/BOM509480
# downloading BSE/BOM509486
# downloading BSE/BOM509488
# downloading BSE/BOM509496
# downloading BSE/BOM509499
# downloading BSE/BOM509525
# downloading BSE/BOM509527
# downloading BSE/BOM509546
# downloading BSE/BOM509550
# downloading BSE/BOM509557
# downloading BSE/BOM509563
# downloading BSE/BOM509567
# downloading BSE/BOM509597
# downloading BSE/BOM509627
# downloading BSE/BOM509631
# downloading BSE/BOM509635
# downloading BSE/BOM509675
# downloading BSE/BOM509692
# downloading BSE/BOM509709
# downloading BSE/BOM509715
# downloading BSE/BOM509760
# downloading BSE/BOM509762
# downloading BSE/BOM509820
# downloading BSE/BOM509835
# downloading BSE/BOM509839
# downloading BSE/BOM509845
# downloading BSE/BOM509870
# downloading BSE/BOM509874
# downloading BSE/BOM509887
# downloading BSE/BOM509895
# downloading BSE/BOM509910
# downloading BSE/BOM509930
# downloading BSE/BOM509945
# downloading BSE/BOM509953
# downloading BSE/BOM509960
# downloading BSE/BOM509966
# downloading BSE/BOM509992
# downloading BSE/BOM510245
# downloading BSE/BOM511000
# downloading BSE/BOM511012
# downloading BSE/BOM511016
# downloading BSE/BOM511024
# downloading BSE/BOM511034
# downloading BSE/BOM511064
# downloading BSE/BOM511066
# downloading BSE/BOM511072
# downloading BSE/BOM511074
# downloading BSE/BOM511076
# downloading BSE/BOM511082
# downloading BSE/BOM511092
# downloading BSE/BOM511108
# downloading BSE/BOM511110
# downloading BSE/BOM511114
# downloading BSE/BOM511116
# downloading BSE/BOM511122
# downloading BSE/BOM511131
# downloading BSE/BOM511138
# downloading BSE/BOM511139
# downloading BSE/BOM511144
# downloading BSE/BOM511147
# downloading BSE/BOM511149
# downloading BSE/BOM511153
# downloading BSE/BOM511169
# downloading BSE/BOM511176
# downloading BSE/BOM511185
# downloading BSE/BOM511187
# downloading BSE/BOM511196
# downloading BSE/BOM511200
# downloading BSE/BOM511208
# downloading BSE/BOM511210
# downloading BSE/BOM511218
# downloading BSE/BOM511243
# downloading BSE/BOM511246
# downloading BSE/BOM511272
# downloading BSE/BOM511276
# downloading BSE/BOM511288
# downloading BSE/BOM511306
# downloading BSE/BOM511333
# downloading BSE/BOM511355
# downloading BSE/BOM511357
# downloading BSE/BOM511359
# downloading BSE/BOM511361
# downloading BSE/BOM511367
# downloading BSE/BOM511369
# downloading BSE/BOM511377
# downloading BSE/BOM511389
# downloading BSE/BOM511391
# downloading BSE/BOM511393
# downloading BSE/BOM511395
# downloading BSE/BOM511401
# downloading BSE/BOM511411
# downloading BSE/BOM511413
# downloading BSE/BOM511421
# downloading BSE/BOM511427
# downloading BSE/BOM511431
# downloading BSE/BOM511433
# downloading BSE/BOM511441
# downloading BSE/BOM511447
# downloading BSE/BOM511451
# downloading BSE/BOM511463
# downloading BSE/BOM511473
# downloading BSE/BOM511489
# downloading BSE/BOM511493
# downloading BSE/BOM511501
# downloading BSE/BOM511503
# downloading BSE/BOM511505
# downloading BSE/BOM511507
# downloading BSE/BOM511509
# downloading BSE/BOM511523
# downloading BSE/BOM511525
# downloading BSE/BOM511533
# downloading BSE/BOM511535
# downloading BSE/BOM511539
# downloading BSE/BOM511543
# downloading BSE/BOM511549
# downloading BSE/BOM511551
# downloading BSE/BOM511557
# downloading BSE/BOM511559
# downloading BSE/BOM511571
# downloading BSE/BOM511577
# downloading BSE/BOM511585
# downloading BSE/BOM511589
# downloading BSE/BOM511593
# downloading BSE/BOM511597
# downloading BSE/BOM511601
# downloading BSE/BOM511605
# downloading BSE/BOM511607
# downloading BSE/BOM511609
# downloading BSE/BOM511611
# downloading BSE/BOM511618
# downloading BSE/BOM511626
# downloading BSE/BOM511628
# downloading BSE/BOM511630
# downloading BSE/BOM511634
# downloading BSE/BOM511636
# downloading BSE/BOM511638
# downloading BSE/BOM511640
# downloading BSE/BOM511642
# downloading BSE/BOM511652
# downloading BSE/BOM511654
# downloading BSE/BOM511658
# downloading BSE/BOM511660
# downloading BSE/BOM511664
# downloading BSE/BOM511668
# downloading BSE/BOM511672
# downloading BSE/BOM511676
# downloading BSE/BOM511682
# downloading BSE/BOM511688
# downloading BSE/BOM511690
# downloading BSE/BOM511692
# downloading BSE/BOM511696
# downloading BSE/BOM511698
# downloading BSE/BOM511700
# downloading BSE/BOM511702
# downloading BSE/BOM511706
# downloading BSE/BOM511710
# downloading BSE/BOM511712
# downloading BSE/BOM511714
# downloading BSE/BOM511716
# downloading BSE/BOM511720
# downloading BSE/BOM511724
# downloading BSE/BOM511726
# downloading BSE/BOM511728
# downloading BSE/BOM511730
# downloading BSE/BOM511734
# downloading BSE/BOM511736
# downloading BSE/BOM511738
# downloading BSE/BOM511740
# downloading BSE/BOM511742
# downloading BSE/BOM511754
# downloading BSE/BOM511756
# downloading BSE/BOM511760
# downloading BSE/BOM511764
# downloading BSE/BOM511766
# downloading BSE/BOM511768
# downloading BSE/BOM512008
# downloading BSE/BOM512017
# downloading BSE/BOM512018
# downloading BSE/BOM512020
# downloading BSE/BOM512022
# downloading BSE/BOM512024
# downloading BSE/BOM512026
# downloading BSE/BOM512036
# downloading BSE/BOM512038
# downloading BSE/BOM512047
# downloading BSE/BOM512048
# downloading BSE/BOM512062
# downloading BSE/BOM512063
# downloading BSE/BOM512067
# downloading BSE/BOM512068
# downloading BSE/BOM512070
# downloading BSE/BOM512075
# downloading BSE/BOM512093
# downloading BSE/BOM512097
# downloading BSE/BOM512099
# downloading BSE/BOM512101
# downloading BSE/BOM512103
# downloading BSE/BOM512105
# downloading BSE/BOM512109
# downloading BSE/BOM512113
# downloading BSE/BOM512117
# downloading BSE/BOM512129
# downloading BSE/BOM512131
# downloading BSE/BOM512135
# downloading BSE/BOM512149
# downloading BSE/BOM512153
# downloading BSE/BOM512161
# downloading BSE/BOM512163
# downloading BSE/BOM512167
# downloading BSE/BOM512169
# downloading BSE/BOM512175
# downloading BSE/BOM512179
# downloading BSE/BOM512191
# downloading BSE/BOM512197
# downloading BSE/BOM512199
# downloading BSE/BOM512207
# downloading BSE/BOM512213
# downloading BSE/BOM512215
# downloading BSE/BOM512217
# downloading BSE/BOM512219
# downloading BSE/BOM512221
# downloading BSE/BOM512229
# downloading BSE/BOM512233
# downloading BSE/BOM512237
# downloading BSE/BOM512247
# downloading BSE/BOM512253
# downloading BSE/BOM512257
# downloading BSE/BOM512267
# downloading BSE/BOM512273
# downloading BSE/BOM512277
# downloading BSE/BOM512279
# downloading BSE/BOM512285
# downloading BSE/BOM512289
# downloading BSE/BOM512296
# downloading BSE/BOM512297
# downloading BSE/BOM512299
# downloading BSE/BOM512301
# downloading BSE/BOM512307
# downloading BSE/BOM512309
# downloading BSE/BOM512311
# downloading BSE/BOM512313
# downloading BSE/BOM512319
# downloading BSE/BOM512329
# downloading BSE/BOM512332
# downloading BSE/BOM512337
# downloading BSE/BOM512341
# downloading BSE/BOM512344
# downloading BSE/BOM512345
# downloading BSE/BOM512355
# downloading BSE/BOM512359
# downloading BSE/BOM512361
# downloading BSE/BOM512367
# downloading BSE/BOM512369
# downloading BSE/BOM512375
# downloading BSE/BOM512377
# downloading BSE/BOM512379
# downloading BSE/BOM512381
# downloading BSE/BOM512393
# downloading BSE/BOM512397
# downloading BSE/BOM512399
# downloading BSE/BOM512405
# downloading BSE/BOM512409
# downloading BSE/BOM512413
# downloading BSE/BOM512415
# downloading BSE/BOM512417
# downloading BSE/BOM512425
# downloading BSE/BOM512437
# downloading BSE/BOM512439
# downloading BSE/BOM512441
# downloading BSE/BOM512443
# downloading BSE/BOM512449
# downloading BSE/BOM512453
# downloading BSE/BOM512455
# downloading BSE/BOM512463
# downloading BSE/BOM512465
# downloading BSE/BOM512477
# downloading BSE/BOM512479
# downloading BSE/BOM512481
# downloading BSE/BOM512485
# downloading BSE/BOM512487
# downloading BSE/BOM512489
# downloading BSE/BOM512493
# downloading BSE/BOM512499
# downloading BSE/BOM512511
# downloading BSE/BOM512519
# downloading BSE/BOM512527
# downloading BSE/BOM512529
# downloading BSE/BOM512531
# downloading BSE/BOM512535
# downloading BSE/BOM512553
# downloading BSE/BOM512559
# downloading BSE/BOM512565
# downloading BSE/BOM512573
# downloading BSE/BOM512579
# downloading BSE/BOM512585
# downloading BSE/BOM512587
# downloading BSE/BOM512589
# downloading BSE/BOM512591
# downloading BSE/BOM512595
# downloading BSE/BOM512597
# downloading BSE/BOM512599
# downloading BSE/BOM512600
# downloading BSE/BOM512604
# downloading BSE/BOM512608
# downloading BSE/BOM512624
# downloading BSE/BOM512626
# downloading BSE/BOM512634
# downloading BSE/BOM513005
# downloading BSE/BOM513010
# downloading BSE/BOM513012
# downloading BSE/BOM513023
# downloading BSE/BOM513039
# downloading BSE/BOM513043
# downloading BSE/BOM513059
# downloading BSE/BOM513063
# downloading BSE/BOM513097
# downloading BSE/BOM513108
# downloading BSE/BOM513117
# downloading BSE/BOM513119
# failed to download BSE/BOM513119
# HTTP Error 429:
# downloading BSE/BOM513121
# failed to download BSE/BOM513121
# HTTP Error 429:
# downloading BSE/BOM513142
# failed to download BSE/BOM513142
# HTTP Error 429:
# downloading BSE/BOM513149
# failed to download BSE/BOM513149
# HTTP Error 429:
# downloading BSE/BOM513151
# failed to download BSE/BOM513151
# HTTP Error 429:
# downloading BSE/BOM513153
# failed to download BSE/BOM513153
# HTTP Error 429:
# downloading BSE/BOM513173
# downloading BSE/BOM513179
# failed to download BSE/BOM513179
# HTTP Error 429:
# downloading BSE/BOM513216
# downloading BSE/BOM513228
# downloading BSE/BOM513250
# downloading BSE/BOM513252
# downloading BSE/BOM513262
# downloading BSE/BOM513265
# downloading BSE/BOM513269
# downloading BSE/BOM513291
# downloading BSE/BOM513295
# downloading BSE/BOM513303
# downloading BSE/BOM513305
# downloading BSE/BOM513307
# downloading BSE/BOM513309
# downloading BSE/BOM513333
# downloading BSE/BOM513335
# downloading BSE/BOM513337
# downloading BSE/BOM513349
# downloading BSE/BOM513353
# downloading BSE/BOM513359
# downloading BSE/BOM513361
# downloading BSE/BOM513369
# downloading BSE/BOM513375
# downloading BSE/BOM513377
# downloading BSE/BOM513397
# downloading BSE/BOM513401
# downloading BSE/BOM513403
# downloading BSE/BOM513405
# downloading BSE/BOM513414
# downloading BSE/BOM513418
# downloading BSE/BOM513422
# downloading BSE/BOM513428
# downloading BSE/BOM513430
# downloading BSE/BOM513434
# downloading BSE/BOM513436
# downloading BSE/BOM513446
# downloading BSE/BOM513452
# downloading BSE/BOM513456
# downloading BSE/BOM513460
# downloading BSE/BOM513472
# downloading BSE/BOM513488
# downloading BSE/BOM513502
# downloading BSE/BOM513507
# downloading BSE/BOM513509
# downloading BSE/BOM513511
# downloading BSE/BOM513513
# downloading BSE/BOM513515
# downloading BSE/BOM513517
# downloading BSE/BOM513519
# downloading BSE/BOM513528
# downloading BSE/BOM513530
# downloading BSE/BOM513532
# downloading BSE/BOM513534
# downloading BSE/BOM513536
# downloading BSE/BOM513540
# downloading BSE/BOM513544
# downloading BSE/BOM513548
# downloading BSE/BOM513554
# downloading BSE/BOM513558
# downloading BSE/BOM513566
# downloading BSE/BOM513575
# downloading BSE/BOM513579
# downloading BSE/BOM513583
# downloading BSE/BOM513597
# downloading BSE/BOM513599
# downloading BSE/BOM513605
# downloading BSE/BOM513611
# downloading BSE/BOM513613
# downloading BSE/BOM513627
# downloading BSE/BOM513629
# downloading BSE/BOM513630
# downloading BSE/BOM513642
# downloading BSE/BOM513648
# downloading BSE/BOM513683
# downloading BSE/BOM513687
# downloading BSE/BOM513691
# downloading BSE/BOM513693
# downloading BSE/BOM513699
# downloading BSE/BOM513703
# downloading BSE/BOM513709
# downloading BSE/BOM513713
# downloading BSE/BOM513721
# downloading BSE/BOM513723
# downloading BSE/BOM513727
# downloading BSE/BOM513729
# downloading BSE/BOM514010
# downloading BSE/BOM514028
# downloading BSE/BOM514030
# downloading BSE/BOM514034
# downloading BSE/BOM514036
# downloading BSE/BOM514043
# downloading BSE/BOM514045
# downloading BSE/BOM514087
# downloading BSE/BOM514113
# downloading BSE/BOM514116
# downloading BSE/BOM514118
# downloading BSE/BOM514128
# downloading BSE/BOM514138
# downloading BSE/BOM514140
# downloading BSE/BOM514142
# downloading BSE/BOM514144
# downloading BSE/BOM514162
# downloading BSE/BOM514165
# downloading BSE/BOM514167
# downloading BSE/BOM514171
# downloading BSE/BOM514175
# downloading BSE/BOM514177
# downloading BSE/BOM514183
# downloading BSE/BOM514199
# downloading BSE/BOM514211
# downloading BSE/BOM514215
# downloading BSE/BOM514221
# downloading BSE/BOM514234
# downloading BSE/BOM514238
# downloading BSE/BOM514240
# downloading BSE/BOM514264
# downloading BSE/BOM514266
# downloading BSE/BOM514272
# downloading BSE/BOM514274
# downloading BSE/BOM514280
# downloading BSE/BOM514286
# downloading BSE/BOM514296
# downloading BSE/BOM514300
# downloading BSE/BOM514302
# downloading BSE/BOM514304
# downloading BSE/BOM514308
# downloading BSE/BOM514312
# downloading BSE/BOM514316
# downloading BSE/BOM514322
# downloading BSE/BOM514324
# downloading BSE/BOM514326
# downloading BSE/BOM514332
# downloading BSE/BOM514336
# downloading BSE/BOM514348
# downloading BSE/BOM514354
# downloading BSE/BOM514358
# downloading BSE/BOM514360
# downloading BSE/BOM514378
# downloading BSE/BOM514386
# downloading BSE/BOM514394
# downloading BSE/BOM514400
# downloading BSE/BOM514412
# downloading BSE/BOM514414
# downloading BSE/BOM514418
# downloading BSE/BOM514428
# downloading BSE/BOM514440
# downloading BSE/BOM514442
# downloading BSE/BOM514446
# downloading BSE/BOM514448
# downloading BSE/BOM514450
# downloading BSE/BOM514454
# downloading BSE/BOM514460
# downloading BSE/BOM514470
# downloading BSE/BOM514474
# downloading BSE/BOM514482
# downloading BSE/BOM514484
# downloading BSE/BOM514486
# downloading BSE/BOM515018
# downloading BSE/BOM515030
# downloading BSE/BOM515037
# downloading BSE/BOM515043
# downloading BSE/BOM515055
# downloading BSE/BOM515059
# downloading BSE/BOM515081
# downloading BSE/BOM515085
# downloading BSE/BOM515093
# downloading BSE/BOM515097
# downloading BSE/BOM515099
# downloading BSE/BOM515127
# downloading BSE/BOM515145
# downloading BSE/BOM515147
# downloading BSE/BOM516003
# downloading BSE/BOM516007
# downloading BSE/BOM516016
# downloading BSE/BOM516020
# downloading BSE/BOM516022
# downloading BSE/BOM516030
# downloading BSE/BOM516032
# downloading BSE/BOM516038
# downloading BSE/BOM516064
# downloading BSE/BOM516072
# downloading BSE/BOM516078
# downloading BSE/BOM516082
# downloading BSE/BOM516086
# downloading BSE/BOM516092
# downloading BSE/BOM516096
# downloading BSE/BOM516106
# downloading BSE/BOM516108
# downloading BSE/BOM516110
# downloading BSE/BOM517001
# downloading BSE/BOM517015
# downloading BSE/BOM517035
# downloading BSE/BOM517041
# downloading BSE/BOM517044
# downloading BSE/BOM517059
# downloading BSE/BOM517063
# downloading BSE/BOM517077
# downloading BSE/BOM517080
# downloading BSE/BOM517096
# downloading BSE/BOM517119
# downloading BSE/BOM517140
# downloading BSE/BOM517146
# downloading BSE/BOM517164
# downloading BSE/BOM517166
# downloading BSE/BOM517168
# downloading BSE/BOM517170
# downloading BSE/BOM517174
# downloading BSE/BOM517201
# downloading BSE/BOM517206
# downloading BSE/BOM517214
# downloading BSE/BOM517224
# downloading BSE/BOM517228
# downloading BSE/BOM517230
# downloading BSE/BOM517236
# downloading BSE/BOM517238
# downloading BSE/BOM517246
# downloading BSE/BOM517258
# downloading BSE/BOM517264
# downloading BSE/BOM517271
# downloading BSE/BOM517288
# downloading BSE/BOM517296
# downloading BSE/BOM517300
# downloading BSE/BOM517320
# downloading BSE/BOM517326
# downloading BSE/BOM517330
# downloading BSE/BOM517334
# downloading BSE/BOM517344
# downloading BSE/BOM517354
# downloading BSE/BOM517356
# downloading BSE/BOM517370
# downloading BSE/BOM517372
# downloading BSE/BOM517374
# downloading BSE/BOM517380
# downloading BSE/BOM517385
# downloading BSE/BOM517391
# downloading BSE/BOM517393
# downloading BSE/BOM517397
# downloading BSE/BOM517399
# downloading BSE/BOM517403
# downloading BSE/BOM517411
# downloading BSE/BOM517415
# downloading BSE/BOM517417
# downloading BSE/BOM517421
# downloading BSE/BOM501144
# downloading BSE/BOM501178
# downloading BSE/BOM501314
# downloading BSE/BOM503639
# downloading BSE/BOM503671
# downloading BSE/BOM503978
# downloading BSE/BOM504397
# downloading BSE/BOM505520
# downloading BSE/BOM506107
# downloading BSE/BOM506162
# downloading BSE/BOM506190
# downloading BSE/BOM509099
# downloading BSE/BOM509650
# downloading BSE/BOM511060
# downloading BSE/BOM511096
# downloading BSE/BOM511128
# downloading BSE/BOM511254
# downloading BSE/BOM512014
# downloading BSE/BOM512025
# downloading BSE/BOM512064
# downloading BSE/BOM512065
# downloading BSE/BOM512091
# downloading BSE/BOM512121
# downloading BSE/BOM512157
# downloading BSE/BOM512165
# downloading BSE/BOM512195
# downloading BSE/BOM512245
# downloading BSE/BOM512261
# downloading BSE/BOM512271
# downloading BSE/BOM512291
# downloading BSE/BOM512408
# downloading BSE/BOM512445
# downloading BSE/BOM512461
# downloading BSE/BOM512505
# downloading BSE/BOM514060
# downloading BSE/BOM514318
# downloading BSE/BOM517429
# downloading BSE/BOM517423
# downloading BSE/BOM517433
# downloading BSE/BOM517447
# downloading BSE/BOM517437
# downloading BSE/BOM517449
# downloading BSE/BOM517463
# downloading BSE/BOM517477
# downloading BSE/BOM517467
# downloading BSE/BOM517481
# downloading BSE/BOM517494
# downloading BSE/BOM517498
# downloading BSE/BOM517496
# downloading BSE/BOM517500
# downloading BSE/BOM517506
# downloading BSE/BOM517514
# downloading BSE/BOM517522
# downloading BSE/BOM517518
# downloading BSE/BOM517530
# downloading BSE/BOM517534
# downloading BSE/BOM517536
# downloading BSE/BOM517544
# downloading BSE/BOM517546
# downloading BSE/BOM517548
# downloading BSE/BOM517554
# downloading BSE/BOM517552
# downloading BSE/BOM517556
# downloading BSE/BOM517562
# downloading BSE/BOM517564
# downloading BSE/BOM517565
# downloading BSE/BOM517569
# downloading BSE/BOM517571
# downloading BSE/BOM517973
# downloading BSE/BOM518011
# downloading BSE/BOM518017
# downloading BSE/BOM518029
# downloading BSE/BOM518075
# downloading BSE/BOM518091
# downloading BSE/BOM519003
# downloading BSE/BOM519014
# downloading BSE/BOM519031
# downloading BSE/BOM519035
# downloading BSE/BOM519039
# downloading BSE/BOM519091
# downloading BSE/BOM519064
# downloading BSE/BOM519097
# downloading BSE/BOM519105
# downloading BSE/BOM519136
# downloading BSE/BOM519126
# downloading BSE/BOM519152
# downloading BSE/BOM519174
# downloading BSE/BOM519156
# downloading BSE/BOM519183
# downloading BSE/BOM519200
# downloading BSE/BOM519214
# downloading BSE/BOM519224
# downloading BSE/BOM519216
# downloading BSE/BOM519230
# downloading BSE/BOM519234
# downloading BSE/BOM519238
# downloading BSE/BOM519242
# downloading BSE/BOM519248
# downloading BSE/BOM519260
# downloading BSE/BOM519262
# downloading BSE/BOM519273
# downloading BSE/BOM519279
# downloading BSE/BOM519281
# downloading BSE/BOM519285
# downloading BSE/BOM519287
# downloading BSE/BOM519295
# downloading BSE/BOM519299
# downloading BSE/BOM519307
# downloading BSE/BOM519303
# downloading BSE/BOM519319
# downloading BSE/BOM519323
# downloading BSE/BOM519331
# failed to download BSE/BOM519331
# HTTP Error 429:
# downloading BSE/BOM519359
# failed to download BSE/BOM519359
# HTTP Error 429:
# downloading BSE/BOM519373
# failed to download BSE/BOM519373
# HTTP Error 429:
# downloading BSE/BOM519383
# failed to download BSE/BOM519383
# HTTP Error 429:
# downloading BSE/BOM519415
# failed to download BSE/BOM519415
# HTTP Error 429:
# downloading BSE/BOM519439
# failed to download BSE/BOM519439
# HTTP Error 429:
# downloading BSE/BOM519421
# failed to download BSE/BOM519421
# HTTP Error 429:
# downloading BSE/BOM519455
# failed to download BSE/BOM519455
# HTTP Error 429:
# downloading BSE/BOM519457
# failed to download BSE/BOM519457
# HTTP Error 429:
# downloading BSE/BOM519475
# failed to download BSE/BOM519475
# HTTP Error 429:
# downloading BSE/BOM519463
# failed to download BSE/BOM519463
# HTTP Error 429:
# downloading BSE/BOM519479
# failed to download BSE/BOM519479
# HTTP Error 429:
# downloading BSE/BOM519483
# failed to download BSE/BOM519483
# HTTP Error 429:
# downloading BSE/BOM519485
# failed to download BSE/BOM519485
# HTTP Error 429:
# downloading BSE/BOM519491
# failed to download BSE/BOM519491
# HTTP Error 429:
# downloading BSE/BOM519500
# downloading BSE/BOM519552
# downloading BSE/BOM519532
# downloading BSE/BOM519560
# downloading BSE/BOM519566
# downloading BSE/BOM519588
# downloading BSE/BOM519570
# downloading BSE/BOM519586
# downloading BSE/BOM519600
# downloading BSE/BOM519604
# downloading BSE/BOM519602
# downloading BSE/BOM519606
# downloading BSE/BOM519612
# downloading BSE/BOM520008
# downloading BSE/BOM520003
# downloading BSE/BOM520021
# downloading BSE/BOM520026
# downloading BSE/BOM520043
# downloading BSE/BOM520051
# downloading BSE/BOM520056
# downloading BSE/BOM520057
# downloading BSE/BOM520059
# downloading BSE/BOM520066
# downloading BSE/BOM520073
# downloading BSE/BOM520075
# downloading BSE/BOM520077
# downloading BSE/BOM520086
# downloading BSE/BOM520081
# downloading BSE/BOM520111
# downloading BSE/BOM520113
# downloading BSE/BOM520119
# downloading BSE/BOM520115
# downloading BSE/BOM520121
# downloading BSE/BOM520123
# downloading BSE/BOM520139
# downloading BSE/BOM520127
# downloading BSE/BOM520131
# downloading BSE/BOM520141
# downloading BSE/BOM520151
# downloading BSE/BOM520155
# downloading BSE/BOM521003
# downloading BSE/BOM521005
# downloading BSE/BOM521014
# downloading BSE/BOM521018
# downloading BSE/BOM521016
# downloading BSE/BOM521030
# downloading BSE/BOM521022
# downloading BSE/BOM521034
# downloading BSE/BOM521036
# downloading BSE/BOM521046
# downloading BSE/BOM521048
# downloading BSE/BOM521038
# downloading BSE/BOM521054
# downloading BSE/BOM521056
# downloading BSE/BOM521062
# downloading BSE/BOM521064
# downloading BSE/BOM521068
# downloading BSE/BOM521070
# downloading BSE/BOM521076
# downloading BSE/BOM521080
# downloading BSE/BOM521097
# downloading BSE/BOM521082
# downloading BSE/BOM521109
# downloading BSE/BOM521113
# downloading BSE/BOM521127
# downloading BSE/BOM521131
# downloading BSE/BOM521133
# downloading BSE/BOM521137
# downloading BSE/BOM521149
# downloading BSE/BOM521151
# downloading BSE/BOM521161
# downloading BSE/BOM521163
# downloading BSE/BOM521167
# downloading BSE/BOM521174
# downloading BSE/BOM521176
# downloading BSE/BOM521178
# failed to download BSE/BOM521178
# HTTP Error 429:
# downloading BSE/BOM521180
# failed to download BSE/BOM521180
# HTTP Error 429:
# downloading BSE/BOM521182
# failed to download BSE/BOM521182
# HTTP Error 429:
# downloading BSE/BOM521188
# failed to download BSE/BOM521188
# HTTP Error 429:
# downloading BSE/BOM521194
# failed to download BSE/BOM521194
# HTTP Error 429:
# downloading BSE/BOM521200
# downloading BSE/BOM521206
# failed to download BSE/BOM521206
# HTTP Error 429:
# downloading BSE/BOM521210
# failed to download BSE/BOM521210
# HTTP Error 429:
# downloading BSE/BOM521216
# failed to download BSE/BOM521216
# HTTP Error 429:
# downloading BSE/BOM521220
# failed to download BSE/BOM521220
# HTTP Error 429:
# downloading BSE/BOM521222
# failed to download BSE/BOM521222
# HTTP Error 429:
# downloading BSE/BOM521226
# failed to download BSE/BOM521226
# HTTP Error 429:
# downloading BSE/BOM521228
# failed to download BSE/BOM521228
# HTTP Error 429:
# downloading BSE/BOM521232
# failed to download BSE/BOM521232
# HTTP Error 429:
# downloading BSE/BOM521234
# failed to download BSE/BOM521234
# HTTP Error 429:
# downloading BSE/BOM521238
# failed to download BSE/BOM521238
# HTTP Error 429:
# downloading BSE/BOM521240
# failed to download BSE/BOM521240
# HTTP Error 429:
# downloading BSE/BOM521242
# failed to download BSE/BOM521242
# HTTP Error 429:
# downloading BSE/BOM521244
# failed to download BSE/BOM521244
# HTTP Error 429:
# downloading BSE/BOM521246
# failed to download BSE/BOM521246
# HTTP Error 429:
# downloading BSE/BOM521248
# failed to download BSE/BOM521248
# HTTP Error 429:
# downloading BSE/BOM522001
# failed to download BSE/BOM522001
# HTTP Error 429:
# downloading BSE/BOM522004
# failed to download BSE/BOM522004
# HTTP Error 429:
# downloading BSE/BOM522005
# downloading BSE/BOM522014
# failed to download BSE/BOM522014
# HTTP Error 429:
# downloading BSE/BOM522015
# failed to download BSE/BOM522015
# HTTP Error 429:
# downloading BSE/BOM522017
# failed to download BSE/BOM522017
# HTTP Error 429:
# downloading BSE/BOM522027
# failed to download BSE/BOM522027
# HTTP Error 429:
# downloading BSE/BOM522029
# failed to download BSE/BOM522029
# HTTP Error 429:
# downloading BSE/BOM522034
# failed to download BSE/BOM522034
# HTTP Error 429:
# downloading BSE/BOM522036
# failed to download BSE/BOM522036
# HTTP Error 429:
# downloading BSE/BOM522042
# failed to download BSE/BOM522042
# HTTP Error 429:
# downloading BSE/BOM522064
# failed to download BSE/BOM522064
# HTTP Error 429:
# downloading BSE/BOM522073
# failed to download BSE/BOM522073
# HTTP Error 429:
# downloading BSE/BOM522074
# failed to download BSE/BOM522074
# HTTP Error 429:
# downloading BSE/BOM522080
# failed to download BSE/BOM522080
# HTTP Error 429:
# downloading BSE/BOM522085
# failed to download BSE/BOM522085
# HTTP Error 429:
# downloading BSE/BOM522091
# failed to download BSE/BOM522091
# HTTP Error 429:
# downloading BSE/BOM522101
# failed to download BSE/BOM522101
# HTTP Error 429:
# downloading BSE/BOM522105
# downloading BSE/BOM522108
# failed to download BSE/BOM522108
# HTTP Error 429:
# downloading BSE/BOM522113
# failed to download BSE/BOM522113
# HTTP Error 429:
# downloading BSE/BOM522122
# failed to download BSE/BOM522122
# HTTP Error 429:
# downloading BSE/BOM522150
# failed to download BSE/BOM522150
# HTTP Error 429:
# downloading BSE/BOM522134
# failed to download BSE/BOM522134
# HTTP Error 429:
# downloading BSE/BOM522142
# failed to download BSE/BOM522142
# HTTP Error 429:
# downloading BSE/BOM522152
# failed to download BSE/BOM522152
# HTTP Error 429:
# downloading BSE/BOM522163
# failed to download BSE/BOM522163
# HTTP Error 429:
# downloading BSE/BOM522165
# failed to download BSE/BOM522165
# HTTP Error 429:
# downloading BSE/BOM522175
# failed to download BSE/BOM522175
# HTTP Error 429:
# downloading BSE/BOM522183
# failed to download BSE/BOM522183
# HTTP Error 429:
# downloading BSE/BOM522205
# failed to download BSE/BOM522205
# HTTP Error 429:
# downloading BSE/BOM522207
# failed to download BSE/BOM522207
# HTTP Error 429:
# downloading BSE/BOM522195
# failed to download BSE/BOM522195
# HTTP Error 429:
# downloading BSE/BOM522209
# failed to download BSE/BOM522209
# HTTP Error 429:
# downloading BSE/BOM522217
# failed to download BSE/BOM522217
# HTTP Error 429:
# downloading BSE/BOM522215
# failed to download BSE/BOM522215
# HTTP Error 429:
# downloading BSE/BOM522229
# failed to download BSE/BOM522229
# HTTP Error 429:
# downloading BSE/BOM522231
# failed to download BSE/BOM522231
# HTTP Error 429:
# downloading BSE/BOM522233
# failed to download BSE/BOM522233
# HTTP Error 429:
# downloading BSE/BOM522235
# failed to download BSE/BOM522235
# HTTP Error 429:
# downloading BSE/BOM522237
# failed to download BSE/BOM522237
# HTTP Error 429:
# downloading BSE/BOM522245
# failed to download BSE/BOM522245
# HTTP Error 429:
# downloading BSE/BOM522241
# failed to download BSE/BOM522241
# HTTP Error 429:
# downloading BSE/BOM522251
# failed to download BSE/BOM522251
# HTTP Error 429:
# downloading BSE/BOM522249
# failed to download BSE/BOM522249
# HTTP Error 429:
# downloading BSE/BOM522257
# failed to download BSE/BOM522257
# HTTP Error 429:
# downloading BSE/BOM522261
# failed to download BSE/BOM522261
# HTTP Error 429:
# downloading BSE/BOM522259
# failed to download BSE/BOM522259
# HTTP Error 429:
# downloading BSE/BOM522263
# failed to download BSE/BOM522263
# HTTP Error 429:
# downloading BSE/BOM522267
# ...
# failed to download BSE/BOM539099
# HTTP Error 429:
# downloading BSE/BOM539100
# failed to download BSE/BOM539100
# HTTP Error 429:
# downloading BSE/BOM539110
# downloading BSE/BOM539111
# downloading BSE/BOM539101
# failed to download BSE/BOM539101
# HTTP Error 429:
# downloading BSE/BOM539113
# failed to download BSE/BOM539113
# HTTP Error 429:
# downloading BSE/BOM539117
# downloading BSE/BOM539115
# downloading BSE/BOM539112
# failed to download BSE/BOM539112
# HTTP Error 429:
# downloading BSE/BOM539118
# failed to download BSE/BOM539118
# HTTP Error 429:
# downloading BSE/BOM539116
# downloading BSE/BOM539123
# downloading BSE/BOM539122
# downloading BSE/BOM539121
# failed to download BSE/BOM539121
# HTTP Error 429:
# downloading BSE/BOM539114
# failed to download BSE/BOM539114
# HTTP Error 429:
# downloading BSE/BOM539119
# failed to download BSE/BOM539119
# HTTP Error 429:
# downloading BSE/BOM539124
# downloading BSE/BOM539126
# downloading BSE/BOM539125
# failed to download BSE/BOM539125
# HTTP Error 429:
# downloading BSE/BOM539120
# failed to download BSE/BOM539120
# HTTP Error 429:
# downloading BSE/BOM539131
# downloading BSE/BOM539132
# downloading BSE/BOM539133
# failed to download BSE/BOM539133
# HTTP Error 429:
# downloading BSE/BOM539134
# failed to download BSE/BOM539134
# HTTP Error 429:
# downloading BSE/BOM539135
# failed to download BSE/BOM539135
# HTTP Error 429:
# downloading BSE/BOM539137
# failed to download BSE/BOM539137
# HTTP Error 429:
# downloading BSE/BOM539136
# downloading BSE/BOM539138
# downloading BSE/BOM539139
# failed to download BSE/BOM539139
# HTTP Error 429:
# downloading BSE/BOM539141
# failed to download BSE/BOM539141
# HTTP Error 429:
# downloading BSE/BOM539142
# failed to download BSE/BOM539142
# HTTP Error 429:
# downloading BSE/BOM539140
# failed to download BSE/BOM539140
# HTTP Error 429:
# downloading BSE/BOM539143
# downloading BSE/BOM539148
# downloading BSE/BOM539169
# failed to download BSE/BOM539169
# HTTP Error 429:
# downloading BSE/BOM539149
# failed to download BSE/BOM539149
# HTTP Error 429:
# downloading BSE/BOM539179
# failed to download BSE/BOM539179
# HTTP Error 429:
# downloading BSE/BOM539168
# failed to download BSE/BOM539168
# HTTP Error 429:
# downloading BSE/BOM539174
# downloading BSE/BOM539175
# failed to download BSE/BOM539175
# HTTP Error 429:
# downloading BSE/BOM539150
# failed to download BSE/BOM539150
# HTTP Error 429:
# downloading BSE/BOM539176
# downloading BSE/BOM539180
# downloading BSE/BOM539178
# failed to download BSE/BOM539178
# HTTP Error 429:
# downloading BSE/BOM539151
# downloading BSE/BOM539196
# failed to download BSE/BOM539196
# HTTP Error 429:
# downloading BSE/BOM539167
# downloading BSE/BOM539177
# downloading BSE/BOM539195
# downloading BSE/BOM539199
# failed to download BSE/BOM539199
# HTTP Error 429:
# downloading BSE/BOM539189
# failed to download BSE/BOM539189
# HTTP Error 429:
# downloading BSE/BOM539190
# failed to download BSE/BOM539190
# HTTP Error 429:
# downloading BSE/BOM539197
# downloading BSE/BOM539201
# downloading BSE/BOM539198
# downloading BSE/BOM539200
# failed to download BSE/BOM539200
# HTTP Error 429:
# downloading BSE/BOM539203
# downloading BSE/BOM539202
# downloading BSE/BOM539204
# downloading BSE/BOM539205
# failed to download BSE/BOM539205
# HTTP Error 429:
# downloading BSE/BOM539206
# failed to download BSE/BOM539206
# HTTP Error 429:
# downloading BSE/BOM539216
# failed to download BSE/BOM539216
# HTTP Error 429:
# downloading BSE/BOM539207
# failed to download BSE/BOM539207
# HTTP Error 429:
# downloading BSE/BOM539217
# failed to download BSE/BOM539217
# HTTP Error 429:
# downloading BSE/BOM539218
# failed to download BSE/BOM539218
# HTTP Error 429:
# downloading BSE/BOM539220
# failed to download BSE/BOM539220
# HTTP Error 429:
# downloading BSE/BOM539221
# failed to download BSE/BOM539221
# HTTP Error 429:
# downloading BSE/BOM539222
# failed to download BSE/BOM539222
# HTTP Error 429:
# downloading BSE/BOM539223
# failed to download BSE/BOM539223
# HTTP Error 429:
# downloading BSE/BOM539225
# failed to download BSE/BOM539225
# HTTP Error 429:
# downloading BSE/BOM539224
# downloading BSE/BOM539219
# failed to download BSE/BOM539219
# HTTP Error 429:
# downloading BSE/BOM539228
# failed to download BSE/BOM539228
# HTTP Error 429:
# downloading BSE/BOM539226
# failed to download BSE/BOM539226
# HTTP Error 429:
# downloading BSE/BOM539230
# failed to download BSE/BOM539230
# HTTP Error 429:
# downloading BSE/BOM539251
# failed to download BSE/BOM539251
# HTTP Error 429:
# downloading BSE/BOM539227
# failed to download BSE/BOM539227
# HTTP Error 429:
# downloading BSE/BOM539229
# failed to download BSE/BOM539229
# HTTP Error 429:
# downloading BSE/BOM539235
# failed to download BSE/BOM539235
# HTTP Error 429:
# downloading BSE/BOM539253
# downloading BSE/BOM539246
# downloading BSE/BOM539252
# downloading BSE/BOM539254
# failed to download BSE/BOM539254
# HTTP Error 429:
# downloading BSE/BOM539265
# failed to download BSE/BOM539265
# HTTP Error 429:
# downloading BSE/BOM539255
# failed to download BSE/BOM539255
# HTTP Error 429:
# downloading BSE/BOM539266
# failed to download BSE/BOM539266
# HTTP Error 429:
# downloading BSE/BOM539276
# failed to download BSE/BOM539276
# HTTP Error 429:
# downloading BSE/BOM539275
# failed to download BSE/BOM539275
# HTTP Error 429:
# downloading BSE/BOM539277
# downloading BSE/BOM539268
# failed to download BSE/BOM539268
# HTTP Error 429:
# downloading BSE/BOM539285
# failed to download BSE/BOM539285
# HTTP Error 429:
# downloading BSE/BOM539273
# failed to download BSE/BOM539273
# HTTP Error 429:
# downloading BSE/BOM539274
# failed to download BSE/BOM539274
# HTTP Error 429:
# downloading BSE/BOM539267
# failed to download BSE/BOM539267
# HTTP Error 429:
# downloading BSE/BOM539278
# failed to download BSE/BOM539278
# HTTP Error 429:
# downloading BSE/BOM539286
# failed to download BSE/BOM539286
# HTTP Error 429:
# downloading BSE/BOM539289
# failed to download BSE/BOM539289
# HTTP Error 429:
# downloading BSE/BOM539287
# failed to download BSE/BOM539287
# HTTP Error 429:
# downloading BSE/BOM539288
# downloading BSE/BOM539290
# failed to download BSE/BOM539290
# HTTP Error 429:
# downloading BSE/BOM539291
# downloading BSE/BOM539301
# downloading BSE/BOM539300
# failed to download BSE/BOM539300
# HTTP Error 429:
# downloading BSE/BOM539303
# downloading BSE/BOM539311
# downloading BSE/BOM539302
# failed to download BSE/BOM539302
# HTTP Error 429:
# downloading BSE/BOM539304
# downloading BSE/BOM539310
# failed to download BSE/BOM539310
# HTTP Error 429:
# downloading BSE/BOM539309
# failed to download BSE/BOM539309
# HTTP Error 429:
# downloading BSE/BOM539320
# failed to download BSE/BOM539320
# HTTP Error 429:
# downloading BSE/BOM539314
# failed to download BSE/BOM539314
# HTTP Error 429:
# downloading BSE/BOM539321
# failed to download BSE/BOM539321
# HTTP Error 429:
# downloading BSE/BOM539319
# failed to download BSE/BOM539319
# HTTP Error 429:
# downloading BSE/BOM539312
# failed to download BSE/BOM539312
# HTTP Error 429:
# downloading BSE/BOM539322
# failed to download BSE/BOM539322
# HTTP Error 429:
# downloading BSE/BOM539331
# failed to download BSE/BOM539331
# HTTP Error 429:
# downloading BSE/BOM539334
# failed to download BSE/BOM539334
# HTTP Error 429:
# downloading BSE/BOM539333
# downloading BSE/BOM539332
# failed to download BSE/BOM539332
# HTTP Error 429:
# downloading BSE/BOM539335
# failed to download BSE/BOM539335
# HTTP Error 429:
# downloading BSE/BOM539336
# failed to download BSE/BOM539336
# HTTP Error 429:
# downloading BSE/BOM539346
# downloading BSE/BOM539313
# failed to download BSE/BOM539313
# HTTP Error 429:
# downloading BSE/BOM539337
# failed to download BSE/BOM539337
# HTTP Error 429:
# downloading BSE/BOM539352
# failed to download BSE/BOM539352
# HTTP Error 429:
# downloading BSE/BOM539347
# failed to download BSE/BOM539347
# HTTP Error 429:
# downloading BSE/BOM539354
# failed to download BSE/BOM539354
# HTTP Error 429:
# downloading BSE/BOM539378
# failed to download BSE/BOM539378
# HTTP Error 429:
# downloading BSE/BOM539359
# failed to download BSE/BOM539359
# HTTP Error 429:
# downloading BSE/BOM539353
# failed to download BSE/BOM539353
# HTTP Error 429:
# downloading BSE/BOM539351
# downloading BSE/BOM539383
# failed to download BSE/BOM539383
# HTTP Error 429:
# downloading BSE/BOM539363
# failed to download BSE/BOM539363
# HTTP Error 429:
# downloading BSE/BOM539384
# failed to download BSE/BOM539384
# HTTP Error 429:
# downloading BSE/BOM539391
# downloading BSE/BOM539393
# failed to download BSE/BOM539393
# HTTP Error 429:
# downloading BSE/BOM539395
# failed to download BSE/BOM539395
# HTTP Error 429:
# downloading BSE/BOM539394
# failed to download BSE/BOM539394
# HTTP Error 429:
# downloading BSE/BOM539392
# downloading BSE/BOM539396
# failed to download BSE/BOM539396
# HTTP Error 429:
# downloading BSE/BOM539397
# failed to download BSE/BOM539397
# HTTP Error 429:
# downloading BSE/BOM539400
# failed to download BSE/BOM539400
# HTTP Error 429:
# downloading BSE/BOM539399
# failed to download BSE/BOM539399
# HTTP Error 429:
# downloading BSE/BOM539398
# downloading BSE/BOM539403
# failed to download BSE/BOM539403
# HTTP Error 429:
# downloading BSE/BOM539401
# failed to download BSE/BOM539401
# HTTP Error 429:
# downloading BSE/BOM539404
# failed to download BSE/BOM539404
# HTTP Error 429:
# downloading BSE/BOM539405
# failed to download BSE/BOM539405
# HTTP Error 429:
# downloading BSE/BOM539408
# downloading BSE/BOM539406
# failed to download BSE/BOM539406
# HTTP Error 429:
# downloading BSE/BOM539407
# failed to download BSE/BOM539407
# HTTP Error 429:
# downloading BSE/BOM539409
# failed to download BSE/BOM539409
# HTTP Error 429:
# downloading BSE/BOM539420
# failed to download BSE/BOM539420
# HTTP Error 429:
# downloading BSE/BOM539402
# failed to download BSE/BOM539402
# HTTP Error 429:
# downloading BSE/BOM539428
# failed to download BSE/BOM539428
# HTTP Error 429:
# downloading BSE/BOM539421
# downloading BSE/BOM539423
# downloading BSE/BOM539434
# downloading BSE/BOM539422
# downloading BSE/BOM539435
# failed to download BSE/BOM539435
# HTTP Error 429:
# downloading BSE/BOM539446
# downloading BSE/BOM539448
# failed to download BSE/BOM539448
# HTTP Error 429:
# downloading BSE/BOM539447
# failed to download BSE/BOM539447
# HTTP Error 429:
# downloading BSE/BOM539436
# failed to download BSE/BOM539436
# HTTP Error 429:
# downloading BSE/BOM539410
# failed to download BSE/BOM539410
# HTTP Error 429:
# downloading BSE/BOM539433
# failed to download BSE/BOM539433
# HTTP Error 429:
# downloading BSE/BOM539437
# failed to download BSE/BOM539437
# HTTP Error 429:
# downloading BSE/BOM590134
# downloading BSE/BOM501479
# downloading BSE/BOM503622
# failed to download BSE/BOM503622
# HTTP Error 429:
# downloading BSE/BOM504346
# failed to download BSE/BOM504346
# HTTP Error 429:
# downloading BSE/BOM505583
# failed to download BSE/BOM505583
# HTTP Error 429:
# downloading BSE/BOM506178
# failed to download BSE/BOM506178
# HTTP Error 429:
# downloading BSE/BOM511038
# failed to download BSE/BOM511038
# HTTP Error 429:
# downloading BSE/BOM533044
# failed to download BSE/BOM533044
# HTTP Error 429:
# downloading BSE/SENSEX
# failed to download BSE/SENSEX
# HTTP Error 429:
# downloading BSE/SPBSDGDH
# failed to download BSE/SPBSDGDH
# HTTP Error 429:
# downloading BSE/SPBSGLDH
# failed to download BSE/SPBSGLDH
# HTTP Error 429:
# downloading BSE/BSE100
# failed to download BSE/BSE100
# HTTP Error 429:
# downloading BSE/BSE200
# failed to download BSE/BSE200
# HTTP Error 429:
# downloading BSE/BSE500
# failed to download BSE/BSE500
# HTTP Error 429:
# downloading BSE/SPBSE5S
# failed to download BSE/SPBSE5S
# HTTP Error 429:
# downloading BSE/SPBSAIP
# downloading BSE/SI1900
# failed to download BSE/SI1900
# HTTP Error 429:
# downloading BSE/SIBANK
# failed to download BSE/SIBANK
# HTTP Error 429:
# downloading BSE/SPBSBMIP
# failed to download BSE/SPBSBMIP
# HTTP Error 429:
# downloading BSE/SI0200
# failed to download BSE/SI0200
# HTTP Error 429:
# downloading BSE/SPBSCDIP
# failed to download BSE/SPBSCDIP
# HTTP Error 429:
# downloading BSE/SI0400
# failed to download BSE/SI0400
# HTTP Error 429:
# downloading BSE/CPSE
# failed to download BSE/CPSE
# HTTP Error 429:
# downloading BSE/SPBSDSIP
# failed to download BSE/SPBSDSIP
# HTTP Error 429:
# downloading BSE/DOL100
# failed to download BSE/DOL100
# HTTP Error 429:
# downloading BSE/DOLLEX
# downloading BSE/DOLL30
# failed to download BSE/DOLL30
# HTTP Error 429:
# downloading BSE/SPBSENIP
# failed to download BSE/SPBSENIP
# HTTP Error 429:
# downloading BSE/SPBSEVIP
# failed to download BSE/SPBSEVIP
# HTTP Error 429:
# downloading BSE/SI0600
# failed to download BSE/SI0600
# HTTP Error 429:
# downloading BSE/SPBSFIIP
# failed to download BSE/SPBSFIIP
# HTTP Error 429:
# downloading BSE/SI0800
# failed to download BSE/SI0800
# HTTP Error 429:
# downloading BSE/INFRA
# failed to download BSE/INFRA
# HTTP Error 429:
# downloading BSE/SPBIMIP
# downloading BSE/SPBSIDIP
# failed to download BSE/SPBSIDIP
# HTTP Error 429:
# downloading BSE/SI1000
# failed to download BSE/SI1000
# HTTP Error 429:
# downloading BSE/IPO
# failed to download BSE/IPO
# HTTP Error 429:
# downloading BSE/SPBSLIP
# failed to download BSE/SPBSLIP
# HTTP Error 429:
# downloading BSE/SPBSLMIP
# failed to download BSE/SPBSLMIP
# HTTP Error 429:
# downloading BSE/SPBSLVIP
# failed to download BSE/SPBSLVIP
# HTTP Error 429:
# downloading BSE/BSEMID
# failed to download BSE/BSEMID
# HTTP Error 429:
# downloading BSE/SI1200
# downloading BSE/SPBMDSIP
# failed to download BSE/SPBMDSIP
# HTTP Error 429:
# downloading BSE/SPBSMSIP
# failed to download BSE/SPBSMSIP
# HTTP Error 429:
# downloading BSE/SPBSMOIP
# failed to download BSE/SPBSMOIP
# HTTP Error 429:
# downloading BSE/SIPOWE
# failed to download BSE/SIPOWE
# HTTP Error 429:
# downloading BSE/SI1400
# failed to download BSE/SI1400
# HTTP Error 429:
# downloading BSE/SIBPSU
# failed to download BSE/SIBPSU
# HTTP Error 429:
# downloading BSE/SPBSQIP
# failed to download BSE/SPBSQIP
# HTTP Error 429:
# downloading BSE/BSESML
# failed to download BSE/BSESML
# HTTP Error 429:
# downloading BSE/SIREAL
# failed to download BSE/SIREAL
# HTTP Error 429:
# downloading BSE/SPBSSSIP
# failed to download BSE/SPBSSSIP
# HTTP Error 429:
# downloading BSE/SMEIPO
# failed to download BSE/SMEIPO
# HTTP Error 429:
# downloading BSE/SPBSTLIP
# failed to download BSE/SPBSTLIP
# HTTP Error 429:
# downloading BSE/SIBTEC
# failed to download BSE/SIBTEC
# HTTP Error 429:
# downloading BSE/SPBSUTIP
# failed to download BSE/SPBSUTIP
# HTTP Error 429:
# downloading BSE/SPBDISBT
# failed to download BSE/SPBDISBT
# HTTP Error 429:
# downloading BSE/CARBON
# failed to download BSE/CARBON
# HTTP Error 429:
# downloading BSE/GREENX
# downloading BSE/BOM540025
# failed to download BSE/BOM540025
# HTTP Error 429:
# downloading BSE/BOM539523
# failed to download BSE/BOM539523
# HTTP Error 429:
# downloading BSE/BOM539876
# failed to download BSE/BOM539876
# HTTP Error 429:
# downloading BSE/BOM539787
# failed to download BSE/BOM539787
# HTTP Error 429:
# downloading BSE/BOM539844
# failed to download BSE/BOM539844
# HTTP Error 429:
# downloading BSE/BOM539807
# failed to download BSE/BOM539807
# HTTP Error 429:
# downloading BSE/BOM540047
# failed to download BSE/BOM540047
# HTTP Error 429:
# downloading BSE/BOM539524
# failed to download BSE/BOM539524
# HTTP Error 429:
# downloading BSE/BOM539940
# failed to download BSE/BOM539940
# HTTP Error 429:
# downloading BSE/BOM539957
# failed to download BSE/BOM539957
# HTTP Error 429:
# downloading BSE/BOM539542
# failed to download BSE/BOM539542
# HTTP Error 429:
# downloading BSE/BOM539597
# downloading BSE/BOM539981
# failed to download BSE/BOM539981
# HTTP Error 429:
# downloading BSE/BOM539917
# downloading BSE/BOM539551
# failed to download BSE/BOM539551
# HTTP Error 429:
# downloading BSE/BOM539636
# failed to download BSE/BOM539636
# HTTP Error 429:
# downloading BSE/BOM540048
# failed to download BSE/BOM540048
# HTTP Error 429:
# downloading BSE/BOM539889
# failed to download BSE/BOM539889
# HTTP Error 429:
# downloading BSE/BOM539871
# downloading BSE/BOM539450
# failed to download BSE/BOM539450
# HTTP Error 429:
# downloading BSE/BOM539678
# failed to download BSE/BOM539678
# HTTP Error 429:
# downloading BSE/BOM539874
# failed to download BSE/BOM539874
# HTTP Error 429:
# downloading BSE/BOM539658
# failed to download BSE/BOM539658
# HTTP Error 429:
# downloading BSE/SPBSS5IP
# failed to download BSE/SPBSS5IP
# HTTP Error 429:
# downloading BSE/SPBSN5IP
# failed to download BSE/SPBSN5IP
# HTTP Error 429:
# downloading BSE/SPBSB2IP
# failed to download BSE/SPBSB2IP
# HTTP Error 429:
# downloading BSE/SPICBLOT
# failed to download BSE/SPICBLOT
# HTTP Error 429:
# Number of stocks in BSE: 4566
# Number of files downloaded 2496

# %%
def download_code(code):
#     try
    print 'downloading ' + str(code)
    formatted_url = url.format(stock_code=code, api_key=api_key)
    resp = urllib2.urlopen(formatted_url)

    file_name = 'data/' + code.replace('/', '_') + '.csv'
    i=0
    while os.path.isfile(file_name):
        file_name = 'data/' + code.replace('/', '_') + '_' + str(i) + '.csv'
        i += 1

    with open(file_name, 'w') as fp:
        fp.write(resp.read())
#     except Exception as e:
#     print 'failed to download ' + code
#     print str(e)
#     log_file.write(code + ' | ' + str(e) + '\n')

# %%
from time import sleep

btime = 1
def backoff():
    global btime
    if btime <= 120:
        btime += 1
    return btime

def reset_backoff():
    print 'restting backoff to 1 sec'
    global btime
    btime = 1
    

with open('errors.log', 'r') as err_file:
    lines = err_file.readlines()
    
new_errors = open('new_errors.log', 'w')

print 'no of errors: %d' % len(lines)
count = 1
for line in lines:
    code = line.split('|')[0].strip()
    
    while(True):
        try:
            download_code(code)
            reset_backoff()
            break
        except Exception as e:
            print e
            if isinstance(e, urllib2.HTTPError):
                if e.code == 429:
                    btime = backoff()
                    print 'freakin slow site. Sleeping for %d seconds' % btime
                    sleep(btime)
                    continue
                else:
                    print 'wtf' + str(e)
                    new_errors.write(code + ' | ' + str(e) + '\n')
                    break
            else:
                print 'really wtf' + str(e)
                new_errors.write(code + ' | ' + str(e) + '\n')
                break
    # end while
    print 'Downloaded file {x} of {y}'.format(x=count, y=len(lines))
    count += 1
    
new_errors.close()
# Out:
# no of errors: 2070
# downloading BSE/BOM507966
# restting backoff to 1 sec
# Downloaded file 1 of 2070
# downloading BSE/BOM513119
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM513119
# HTTP Error 429:
# freakin slow site. Sleeping for 3 seconds
# downloading BSE/BOM513119
# HTTP Error 429:
# freakin slow site. Sleeping for 4 seconds
# downloading BSE/BOM513119
# HTTP Error 429:
# freakin slow site. Sleeping for 5 seconds
# downloading BSE/BOM513119
# HTTP Error 429:
# freakin slow site. Sleeping for 6 seconds
# downloading BSE/BOM513119
# restting backoff to 1 sec
# Downloaded file 2 of 2070
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 3 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 4 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 5 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 6 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 7 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 8 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 9 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 10 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 11 seconds
# downloading BSE/BOM513121
# HTTP Error 429:
# freakin slow site. Sleeping for 12 seconds
# downloading BSE/BOM513121
# restting backoff to 1 sec
# Downloaded file 3 of 2070
# downloading BSE/BOM513142
# restting backoff to 1 sec
# Downloaded file 4 of 2070
# downloading BSE/BOM513149
# restting backoff to 1 sec
# Downloaded file 5 of 2070
# downloading BSE/BOM513151
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM513151
# restting backoff to 1 sec
# Downloaded file 6 of 2070
# downloading BSE/BOM513153
# restting backoff to 1 sec
# Downloaded file 7 of 2070
# downloading BSE/BOM513179
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM513179
# restting backoff to 1 sec
# Downloaded file 8 of 2070
# downloading BSE/BOM519331
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM519331
# HTTP Error 429:
# freakin slow site. Sleeping for 3 seconds
# downloading BSE/BOM519331
# restting backoff to 1 sec
# Downloaded file 9 of 2070
# downloading BSE/BOM519359
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM519359
# restting backoff to 1 sec
# Downloaded file 10 of 2070
# downloading BSE/BOM519373
# restting backoff to 1 sec
# Downloaded file 11 of 2070
# downloading BSE/BOM519383
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM519383
# restting backoff to 1 sec
# Downloaded file 12 of 2070
# downloading BSE/BOM519415
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM519415
# HTTP Error 429:
# freakin slow site. Sleeping for 3 seconds
# downloading BSE/BOM519415
# HTTP Error 429:
# freakin slow site. Sleeping for 4 seconds
# downloading BSE/BOM519415
# HTTP Error 429:
# freakin slow site. Sleeping for 5 seconds
# downloading BSE/BOM519415
# HTTP Error 429:
# freakin slow site. Sleeping for 6 seconds
# downloading BSE/BOM519415
# restting backoff to 1 sec
# Downloaded file 13 of 2070
# downloading BSE/BOM519439
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM519439
# HTTP Error 429:
# freakin slow site. Sleeping for 3 seconds
# downloading BSE/BOM519439
# restting backoff to 1 sec
# Downloaded file 14 of 2070
# downloading BSE/BOM519421
# HTTP Error 429:
# freakin slow site. Sleeping for 2 seconds
# downloading BSE/BOM519421
# HTTP Error 429:
# freakin slow site. Sleeping for 3 seconds
# downloading BSE/BOM519421
